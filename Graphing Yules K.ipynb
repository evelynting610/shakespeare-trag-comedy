# %%
import psycopg2

try:
    conn = psycopg2.connect("dbname='shakespeare' user='evelynting' host='localhost' password='password'")
except:
    print("couldn't connect to db")
cursor = conn.cursor()

# %%
import pandas as pd

sql_string = "SELECT play, avg(yulek) as yuleK FROM yulek WHERE PLAY_TYPE = 'comedy' and id != 'Wiv54' GROUP BY play;"
comedy_df = pd.read_sql(sql_string, conn)
comedy_df.index = comedy_df['play']
comedy_df.head()
# Out:
#      play       avg
# play
# MND   MND  0.008147
# AYL   AYL  0.008960
# Err   Err  0.008495
# Wiv   Wiv  0.009108
# Ado   Ado  0.008359

# %%
sql_string = "SELECT play, avg(yulek) as yuleK FROM yulek WHERE PLAY_TYPE = 'tragedy' GROUP BY play;"
tragedy_df = pd.read_sql(sql_string, conn)
tragedy_df.index = tragedy_df['play']
tragedy_df.head()
# Out:
#      play     yulek
# play
# Ham   Ham  0.008017
# Ant   Ant  0.006964
# Mac   Mac  0.007446
# Lr     Lr  0.007365
# Oth   Oth  0.007632

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
plt.figure(figsize=(17, 10))    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)    
  
# Ensure that the axis ticks only show up on the bottom and left of the plot.    
# Ticks on the right and top of the plot are generally unnecessary chartjunk.    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()
ax.set_title('Comedy Yules-K', fontsize= 20)
ax.set_ylabel('Yules - K', fontsize = 16)
ax.set_xlabel('Play Scenes', fontsize = 16)

plt.xticks(fontsize=14, rotation=45)
plt.yticks(fontsize=14)

comedy_df.plot(kind = 'bar', ax=ax, lw=2.5, rot=45)

# %%
plt.figure(figsize=(17, 10))    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)    
  
# Ensure that the axis ticks only show up on the bottom and left of the plot.    
# Ticks on the right and top of the plot are generally unnecessary chartjunk.    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()
ax.set_title('Tragedy Yules-K', fontsize= 20)
ax.set_ylabel('Yules - K', fontsize = 16)
ax.set_xlabel('Play Scenes', fontsize = 16)

plt.xticks(fontsize=14, rotation=45)
plt.yticks(fontsize=14)

tragedy_df.plot(kind = 'bar', ax=ax, lw=2.5, rot=45)
