# %%
import os, sys, json
import pandas as pd

dir_name = "/Users/evelyn/Desktop/success_dashboard/rover/rover_captured_tickets"
files = [f for f in os.listdir(dir_name) ]
df_1 = None
for file_name in files:
    with open(dir_name + '/' + file_name) as f:
        df_i=pd.DataFrame(json.loads(l.replace('\n', '')) for l in f)
    if df_1 is None:
        df_1 = df_i
    else:
        df_1 = df_1.append(df_i, ignore_index=True)

# %%
df_1.head(10)
# Out:
#    captured_at                       emailAddress helpDeskId questionCategory  \
# 0   1463268535               charli1441@gmail.com     646548
# 1   1463269340  tbgprintstore@thebernardgroup.com     646555
# 2   1463269994             casabelarica@gmail.com     646559
# 3   1463270710                rascal049@gmail.com     646563
# 4   1463268486              johnsshy000@gmail.com     646547
# 5   1463268568                mejia8715@yahoo.com     646550
# 6   1463268750                  systems@rover.com     646554
# 7   1463269712               andreav3ga@gmail.com     646557
# 8   1463268626               taysiagray@gmail.com     646551
# 9   1463270473            stacylarsen16@gmail.com     646560
#
#                                     questionMetadata       source subject  \
# 0  {u'Category': None, u'Source': None, u'Custome...     Web Form
# 1  {u'Category': None, u'Source': None, u'Custome...         Mail
# 2  {u'Category': None, u'Source': None, u'Custome...  Web Service
# 3  {u'Category': None, u'Source': None, u'Custome...     Web Form
# 4  {u'Category': None, u'Source': None, u'Custome...     Web Form
# 5  {u'Category': None, u'Source': None, u'Custome...  Web Service
# 6  {u'Category': None, u'Source': None, u'Custome...  Web Service
# 7  {u'Category': None, u'Source': None, u'Custome...  Web Service
# 8  {u'Category': None, u'Source': None, u'Custome...     Web Form
# 9  {u'Category': None, u'Source': None, u'Custome...     Web Form
#
#                                                 tags  \
# 0  getting_started_how_does_rover_work macro::pho...
# 1                                              email
# 2                   api nosend refund_request sitter
# 3  agent_email lost_dog_checklist macro::situatio...
# 4  macro::phone-call payments_pay_in phone repeat...
# 5                   api nosend refund_request sitter
# 6                4_star api nosend owner stay_review
# 7                   api nosend refund_request sitter
# 8  agent_email macro::reservation-guarantee::fina...
# 9  managing_my_account__editing_my_sitter_profile...
#
#                                                 text
# 0  Charli Ohlson\nxxxx@xxxx.xxx\nPhone Number: (x...
# 1  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 T...
# 2  Incoming Cancellation Request for conversation...
# 3  Hello Nancy,\n\nWe have been informed by Rosie...
# 4  Shyla Johnson\nEmail: xxxx@xxxx.xxx\nPhone Num...
# 5  Incoming Cancellation Request for conversation...
# 6  Krystal Smith left a 4-star review of Pogi's s...
# 7  Incoming Cancellation Request for conversation...
# 8  Hello Taysia,  \n\nYour satisfaction is import...
# 9  If you search my area i do not show up even th...

# %%
df_1["tags"].to_csv("rovertags.csv")

# %%
df_1['safe_text'] = df_1.apply(lambda x: x['text'].replace('\n', ' '), axis=1)

# %%
df_1["safe_text"].to_csv("rovertext.csv", encoding="utf-8")
